# %% [markdown]
# # Identifying problems around central obstacle/clock

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
import pandas as pd
import pickle
import seaborn as sns
import sys
from tqdm import tqdm

# %%
sys.path.append('../../../stationsim/')

from ensemble_kalman_filter import EnsembleKalmanFilter, EnsembleKalmanFilterType, ActiveAgentNormaliser
from stationsim_gcs_model import Model

# %%
sys.path.append('../')

from experiment_utils import Modeller, Processor, Visualiser

# %%
# %matplotlib inline

# %% [markdown]
# ### Paths and directories

# %%
results_dir = '../results/'
model_output_dir = results_dir + 'models/gcs_model/clock/'
fig_output_dir = results_dir + 'figures/gcs_model/clock/'
data_output_dir = results_dir + 'data/gcs_model/clock/'

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Model animations

# %% [markdown]
# Run an instance of the model:

# %%
# Set parameter values
model_params = {'pop_total': 50,
                'station': 'Grand_Central',
                'do_print': False}

# Create model instance
model = Model(**model_params)

# Set model forward
for _ in range(model.step_limit):
    model.step()

# %% [markdown]
# Produce an animation of the agents in the model:

# %%
# Get and display animation
ani = model.get_ani(show_separation=True)
HTML(ani.to_html5_video())
# Out:
# <video width="1280" height="1210" controls autoplay loop>
#   <source type="video/mp4" src="...
